# %% [markdown]
# # joining tables
# a key concept for tidy data is the separation of data into tables, such that only relevant data is stored in each table. this reduces data size and increases readability.
#
# however, what data are relevant together can change based on the use case, so we often need to bring together into a single table information from two or more tables. the `join` operations that do this are the topic of today's session.
#
# ## today's exercise
# consider the new york rodent inspection dataset from last time. we have already discussed how to read in that data, how to clean/manipulate the datetime information in it, and how to use group by and aggregation to calculate things like the monthly number of inspections.
#
# one might suspect that the weather plays a role in how many rodent inspections occur in a given day/week/month. to explore that hypothesis we must join the data on daily new york rodent inspection counts with data on the daily weather in new york. in the `data` folder there is a data file containing the daily weather summary for new york. read it in, count the number of inspections per day and join the result with the daily weather (precipitation (`PRCP` and `SNOW`) and temperature (`TMAX`, `TMIN`, and `TAVG`). then calculate the average number of daily inspections for days when the precipitation is nonzero, and the average number of daily inspaections for days when the precipitation is zero.
#
# ## note on image credits
# this notebook contains links to animated gifs which i copied from here: https://github.com/gadenbuie/tidyexplain

# %% [markdown]
# # the art of the join
# - in the following, when we talk of tables we mean a `pandas` dataframe.
# - when we talk about joining tables, order matters. that is, joining table `x` with table `y` is in general not the same as joining `y` to `x`.
# - in order to be able to join two tables into a single table, they must have at least one column in common, a column that is the key to the join and lets us know which row of one table to match against the other.
# - the resulting joined table retains some subset of the rows and columns of the two tables.
# - we will be using the `pd.merge()` function:
# ```
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
#          left_index=False, right_index=False, sort=True,
#          suffixes=('_x', '_y'), copy=True, indicator=False,
#          validate=None)
# ```
# consider two tables, `x` and `y` defined as dataframes below (for comparison to this week's exercise, imagine  `x` has information on the count of inspections per day, and table `y` has the daily weather information):

# %%
import pandas as pd
x = pd.DataFrame([{'a':1, 'b':'x1'}, {'a':2, 'b':'x2'}, {'a':3, 'b':'x3'}], index=[1,2,3])
y = pd.DataFrame([{'a':1, 'c':'y1'}, {'a':2, 'c':'y2'}, {'a':4, 'c':'y4'}], index=[11,12,13])

# %%
print(x)
# Out:
#    a   b
# 1  1  x1
# 2  2  x2
# 3  3  x3

# %%
print(y)
# Out:
#     a   c
# 11  1  y1
# 12  2  y2
# 13  4  y4

# %% [markdown]
# note that `x` and `y` have one column in common: column `a`. each dataframe also has another column unique to itself.
# it is a good idea to pause here and think about what you expect the resulting joined table to look like? in fact there are several different ways to join these tables with different results.
#
# let's start with the simplest.

# %% [markdown]
# ## full outer join
# a *full outer join* of `x` and `y` is a table containing all the rows of `x` and all the rows of `y`, matched up on columns in common. wherever one table has a gap (lacks a value of the key), a `NaN` is inserted in its columns.
# ![full join](images/full-join.gif)
# this is the kind of join we would use when we are concerned about not dropping any of the data.
#
# here is how we can execute this kind of join:

# %%
outer_join = pd.merge(x,y,how='outer')
print(outer_join)
# Out:
#    a    b    c
# 0  1   x1   y1
# 1  2   x2   y2
# 2  3   x3  NaN
# 3  4  NaN   y4

# %% [markdown]
# note that the index is not being used.

# %% [markdown]
# ## inner join
# an *inner join* of `x` and `y` is a table containing only the rows of `x` and only the rows of `y` that have a match in the key column.
# ![inner join](images/inner-join.gif)
# this is the kind of join we would often use when we want to investigate (model or plot) the relantionship between columns `b` and `c` and cannot use rows where either is missing.

# %%
inner_join = pd.merge(x, y, how='inner', on='a')
print(inner_join)
# Out:
#    a   b   c
# 0  1  x1  y1
# 1  2  x2  y2

# %% [markdown]
# ## left join
# a *left join* of `x` and `y` is a table containing all the rows of `x` and only the rows of `y` which have matching values in the key column(s).
# ![left join](images/left-join.gif)
# this is the most frequently used type of join. we use this kind of join when `x` is our main data table that we do not want to drop rows from, but we are augmenting it with some other external data, `y`.

# %%
left_join = pd.merge(x,y,how='left', on='a')
print(left_join)
# Out:
#    a   b    c
# 0  1  x1   y1
# 1  2  x2   y2
# 2  3  x3  NaN

# %% [markdown]
# ## right join
# a *right join* of `x` and `y` is a table containing all the rows of `y` and only the rows of `x` which have matching values in the key column(s).
# ![right join](images/right-join.gif)
# right join of `x` and `y` is exactly like a left join of `y` and `x`. what matters is which table is the one whose data we are not willing to drop in case of missing key values

# %%
left_join = pd.merge(x,y,how='right')
print(left_join)
# Out:
#    a    b   c
# 0  1   x1  y1
# 1  2   x2  y2
# 2  4  NaN  y4

# %% [markdown]
# ## specifying columns
# in case there are no identically named columns between the two tables, we must specify the column in each table

# %%
x = pd.DataFrame([{'x_a':1, 'x_b':'x1'}, {'x_a':2, 'x_b':'x2'}, {'x_a':3, 'x_b':'x3'}], index=[1,2,3])
print(x)
y = pd.DataFrame([{'y_a':1, 'y_c':'y1'}, {'y_a':2, 'y_c':'y2'}, {'y_a':4, 'y_c':'y4'}], index=[1,2,3])
print(y)
# Out:
#    x_a x_b
# 1    1  x1
# 2    2  x2
# 3    3  x3
#    y_a y_c
# 1    1  y1
# 2    2  y2
# 3    4  y4

# %%
inner_join = pd.merge(x, y, how='inner', left_on='x_a', right_on='y_a')
print(inner_join)
# Out:
#    x_a x_b  y_a y_c
# 0    1  x1    1  y1
# 1    2  x2    2  y2

# %%
left_join = pd.merge(x, y, how='left', left_on='x_a', right_on='y_a').drop(['y_a'], axis=1)
print(left_join)
# Out:
#    x_a x_b  y_c
# 0    1  x1   y1
# 1    2  x2   y2
# 2    3  x3  NaN

# %% [markdown]
# # filtered joins

# %% [markdown]
# ## left semi join
# a *left semi join* of `x` and `y` is a table which retains only the columns of `x` and only the rows where `x` and `y` have matching keys. i
# ![semi join](images/semi-join.gif)
# (a rarely-seen *right semi join* works similarly) in effect, the rows of `x` get filtered by the intersection of the keys in `x` and `y`. we use a semi join to trim a dataframe based on another dataframe or list.

# %%
boolean_mask = x['a'].isin(y['a'])
print(boolean_mask)
semi_join = x.loc[boolean_mask]
print(semi_join)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/Python_and_automation-eeU3geaT/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3d0cb58793a2> in <module>
# ----> 1 boolean_mask = x['a'].isin(y['a'])
#       2 print(boolean_mask)
#       3 semi_join = x.loc[boolean_mask]
#       4 print(semi_join)
#
# ~/.local/share/virtualenvs/Python_and_automation-eeU3geaT/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.local/share/virtualenvs/Python_and_automation-eeU3geaT/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.local/share/virtualenvs/Python_and_automation-eeU3geaT/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.local/share/virtualenvs/Python_and_automation-eeU3geaT/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/share/virtualenvs/Python_and_automation-eeU3geaT/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'

# %% [markdown]
# ## intersect
# when `x` and `y` have some number of columns in common, an *intersect join* of `x` and `y` is a table with the common columns, containing only the rows of `x` and `y` which have matching values in those columns, dropping the rows that only occur in each tables.
# ![intersect join](images/intersect.gif)

# %%
x = pd.DataFrame([{'a':1, 'b':'x1'}, {'a':2, 'b':'x2'}, {'a':3, 'b':'x3'}])
y = pd.DataFrame([{'a':1, 'b':'x1', 'c':'y1'}, {'a':2, 'b':'x4', 'c':'y2'}, {'a':4, 'b':'x1', 'c':'y4'}])
print(x)
print(y)

# %%
boolean_mask = x['a'].isin(y['a']) & x['b'].isin(y['b'])
#print(boolean_mask)
intersect = y.loc[boolean_mask].drop(['c'], axis=1)
print(intersect)

# %% [markdown]
# this gets simpler when the dataframes have the same columns:

# %%
x = pd.DataFrame([{'col1':1, 'col2':'a'}, {'col1':1, 'col2':'b'}, {'col1':2, 'col2':'a'}])
y = pd.DataFrame([{'col1':1, 'col2':'a'}, {'col1':2, 'col2':'b'}])
print(x)
print(y)

# %%
intersect_join = pd.merge(x,y,how='inner')
print(intersect_join)

# %% [markdown]
# # Exercise solution

# %%
import pandas as pd
from datetime import datetime

# %%
filename_csv = 'data/NY_rodent_inspections_sample.csv' # for full on run
rodent_df = pd.read_csv(filename_csv) 
# inspect the data frame
# rodent_df.shape
rodent_df.head
# Out:
# <bound method NDFrame.head of      INSPECTION_TYPE  JOB_TICKET_OR_WORK_ORDER_ID    JOB_ID  JOB_PROGRESS  \
# 0               BAIT                            1   PO12965             3
# 1               BAIT                            2   PO12966             3
# 2               BAIT                           30   PO16966             3
# 3               BAIT                           31   PO13665             3
# 4               BAIT                           38   PO11291             3
# 5               BAIT                           39   PO12483             3
# 6               BAIT                           41   PO25356             3
# 7               BAIT                           46   PO16381             3
# 8               BAIT                           48   PO11801             3
# 9               BAIT                           50   PO11803             3
# 10              BAIT                           51   PO11817             3
# 11              BAIT                           52   PO11077             3
# 12              BAIT                           53   PO15241             3
# 13              BAIT                           57   PO10580             3
# 14              BAIT                           58   PO13111             3
# 15              BAIT                           59   PO10759             3
# 16              BAIT                           60   PO11965             3
# 17              BAIT                           61   PO11019             3
# 18              BAIT                           63   PO10782             3
# 19              BAIT                           66   PO10165             3
# 20              BAIT                           73   PO13732             3
# 21              BAIT                           77   PO13369             3
# 22              BAIT                           84   PO12817             3
# 23              BAIT                           85   PO14758             3
# 24              BAIT                           88   PO11791             3
# 25              BAIT                           90   PO11841             3
# 26              BAIT                           91   PO11717             3
# 27              BAIT                          101   PO14335             3
# 28              BAIT                          103   PO10576             3
# 29              BAIT                          105   PO12629             3
# ...              ...                          ...       ...           ...
# 9969            BAIT                        23663  PO106434             6
# 9970            BAIT                        23664  PO106433             6
# 9971            BAIT                        23665  PO106432             6
# 9972            BAIT                        23667   PO66210             5
# 9973            BAIT                        23671   PO63154             6
# 9974            BAIT                        23672   PO63195             5
# 9975            BAIT                        23673   PO83043             5
# 9976            BAIT                        23675   PO86856             5
# 9977            BAIT                        23676   PO83535             6
# 9978            BAIT                        23677   PO87843             6
# 9979            BAIT                        23678   PO99677             6
# 9980            BAIT                        23686  PO107560             2
# 9981            BAIT                        23805  PO123826             4
# 9982            BAIT                        23806  PO123815             4
# 9983            BAIT                        23807  PO124469             4
# 9984            BAIT                        23808  PO124270             4
# 9985            BAIT                        23809  PO123873             4
# 9986            BAIT                        23811  PO123602             4
# 9987            BAIT                        23813  PO124436             4
# 9988            BAIT                        23814  PO124453             4
# 9989            BAIT                        23815  PO124451             4
# 9990            BAIT                        23816  PO124452             4
# 9991            BAIT                        23817  PO124205             4
# 9992            BAIT                        23820  PO123787             4
# 9993            BAIT                        23823  PO123783             4
# 9994            BAIT                        23826  PO107033             5
# 9995            BAIT                        23827   PO69910             6
# 9996            BAIT                        23828   PO37474             8
# 9997            BAIT                        23830   PO84268             5
# 9998            BAIT                        23831   PO59293            11
#
#              BBL  BORO_CODE  BLOCK  LOT HOUSE_NUMBER           STREET_NAME  \
# 0     1011470035          1   1147   35          104        WEST 76 STREET
# 1     1011470034          1   1147   34          102        WEST 76 STREET
# 2     2043370027          2   4337   27          620        THWAITES PLACE
# 3     2037670077          2   3767   77         1227      WHITEPLAINS ROAD
# 4     1011690057          1   1169   57         2199              BROADWAY
# 5     1015340012          1   1534   12          232        EAST 89 STREET
# 6     1015860005          1   1586    5          515        EAST 89 STREET
# 7     2028140048          2   2814   48         1952        ANTHONY AVENUE
# 8     2026930022          2   2693   22         1230       PROSPECT AVENUE
# 9     2026930008          2   2693    8         1198       PROSPECT AVENUE
# 10    1003770026          1    377   26          390         EAST 8 STREET
# 11    1003890019          1    389   19          202         EAST 7 STREET
# 12    1004590040          1    459   40           19         EAST 3 STREET
# 13    1002100005          1    210    5          336          CANAL STREET
# 14    1003920010          1    392   10          350        EAST 10 STREET
# 18    (40.8131643309274, -73.9426104832865)
# 19     (40.8300466340453, -73.941699773442)
# 20     (40.8385580327087, -73.936585783534)
# 21     (40.844669486257, -73.9347691952077)
# 22    (40.7289253286763, -73.9866106472347)
# 23    (40.7312004499725, -73.9843803591535)
# 24     (40.768386131078, -73.9533243006866)
# 25     (40.7831856237632, -73.946691428707)
# 26    (40.7952306804656, -73.9492893669947)
# 27    (40.7794707699529, -73.9756237844939)
# 28      (40.77334648331, -73.9881253149363)
# 29    (40.7801418293715, -73.9831339876533)
# ...                                     ...
# 9969  (40.6895737131887, -73.9527893456412)
# 9970  (40.6894776020739, -73.9526812320327)
# 9971  (40.6896229510304, -73.9523818256282)
# 9972  (40.6786547628795, -73.9800724556327)
# 9973  (40.7330760527151, -73.9946561933202)
# 9974   (40.7336194841174, -73.994046351835)
# 9975  (40.7127264049032, -73.9944089320782)
# 9976  (40.7132134151726, -73.9948033151718)
# 9977  (40.7248051728811, -73.9803039967851)
# 9978  (40.7282632531992, -73.9785999260222)
# 9979    (40.72535029277, -73.9855517259032)
# 9980  (40.7139271635037, -73.8279891851757)
# 9981  (40.8258524554739, -73.8961110640611)
# 9982  (40.8252208136402, -73.8961181419837)
# 9983  (40.8225430430458, -73.8953795299481)
# 9984  (40.8231464587412, -73.8954952310811)
# 9985  (40.8248776736064, -73.8951813296861)
# 9986  (40.8274319686584, -73.8980904937896)
# 9987  (40.8186760242524, -73.8996170456372)
# 9988  (40.8201310209039, -73.8975963077973)
# 9989  (40.8207420244034, -73.8972187135464)
# 9990  (40.8204738315909, -73.8972922812013)
# 9991  (40.8222812434217, -73.8971906702658)
# 9992    (40.82531300756, -73.8964910829487)
# 9993  (40.8255470401929, -73.8964886688692)
# 9994  (40.7077744363728, -73.8017444698633)
# 9995  (40.8788397683361, -73.9017406808259)
# 9996  (40.8549066197023, -73.9130302748932)
# 9997  (40.8293887213765, -73.9121234267685)
# 9998  (40.8460651323037, -73.9115881298086)
#
# [9999 rows x 20 columns]>

# %%
weather_filename = "data/ny_weather_data_daily.csv"
weather_df = pd.read_csv(weather_filename)

# %%
format_descriptor = '%m/%d/%Y %I:%M:%S %p'
rodent_df['inspection_datetime']   = rodent_df.apply(lambda row: datetime.strptime(row['INSPECTION_DATE'], format_descriptor), axis=1)
rodent_df['inspection_day']      = rodent_df.apply(lambda row: row['inspection_datetime'].strftime("%Y-%m-%d"),   axis=1)

# %%
rodent_df['inspection_day']
# Out:
# 0       2009-10-14
# 1       2009-10-14
# 2       2009-11-09
# 3       2009-11-09
# 4       2009-11-10
# 5       2009-11-10
# 6       2009-11-10
# 7       2009-11-16
# 8       2009-11-16
# 9       2009-11-16
# 10      2009-11-16
# 11      2009-11-16
# 12      2009-11-16
# 13      2009-11-17
# 14      2009-11-17
# 15      2009-11-17
# 16      2009-11-17
# 17      2009-11-17
# 18      2009-11-18
# 19      2009-11-18
# 20      2009-11-20
# 21      2009-11-20
# 22      2009-11-20
# 23      2009-11-20
# 24      2009-11-20
# 25      2009-11-20
# 26      2009-11-20
# 27      2009-11-23
# 28      2009-11-23
# 29      2009-11-23
#            ...
# 9969    2010-07-14
# 9970    2010-07-14
# 9971    2010-07-14
# 9972    2010-07-06
# 9973    2010-07-14
# 9974    2010-07-14
# 9975    2010-07-14
# 9976    2010-07-14
# 9977    2010-07-14
# 9978    2010-07-14
# 9979    2010-07-14
# 9980    2010-07-15
# 9981    2010-07-15
# 9982    2010-07-15
# 9983    2010-07-15
# 9984    2010-07-15
# 9985    2010-07-15
# 9986    2010-07-15
# 9987    2010-07-15
# 9988    2010-07-15
# 9989    2010-07-15
# 9990    2010-07-15
# 9991    2010-07-15
# 9992    2010-07-15
# 9993    2010-07-15
# 9994    2010-07-15
# 9995    2010-07-15
# 9996    2010-07-15
# 9997    2010-07-15
# 9998    2010-07-15
# Name: inspection_day, Length: 9999, dtype: object

# %%
weather_format_descriptor = '%Y-%m-%d'

weather_df["day"] = weather_df.apply(lambda row: datetime.strptime(row['DATE'], weather_format_descriptor), axis=1)

# %%
weather_df["day"].describe()
# Out:
# count                    3591
# unique                   3591
# top       2015-10-18 00:00:00
# freq                        1
# first     2009-01-01 00:00:00
# last      2018-10-31 00:00:00
# Name: day, dtype: object

# %%
inspection_day_counts = rodent_df.groupby('inspection_day').agg({'inspection_day':'count'})
inspection_day_counts = inspection_day_counts.rename(columns={"inspection_day" : "day_counts"})
# inspection_day_counts.reindex()
inspection_day_counts["date"] = inspection_day_counts.index
inspection_day_counts.head()
# Out:
#                 day_counts        date
# inspection_day
# 2009-01-16               1  2009-01-16
# 2009-10-14               2  2009-10-14
# 2009-11-09               2  2009-11-09
# 2009-11-10               3  2009-11-10
# 2009-11-16               6  2009-11-16

# %%
inspection_day_counts["day"] = inspection_day_counts.index

# %%
inspection_day_counts["date"] = pd.to_datetime(inspection_day_counts["date"])

# %%
inspection_day_counts.head()
# Out:
#                 day_counts       date         day
# inspection_day
# 2009-01-16               1 2009-01-16  2009-01-16
# 2009-10-14               2 2009-10-14  2009-10-14
# 2009-11-09               2 2009-11-09  2009-11-09
# 2009-11-10               3 2009-11-10  2009-11-10
# 2009-11-16               6 2009-11-16  2009-11-16

# %%
inspection_day_counts
# Out:
#                 day_counts       date         day
# inspection_day
# 2009-01-16               1 2009-01-16  2009-01-16
# 2009-10-14               2 2009-10-14  2009-10-14
# 2009-11-09               2 2009-11-09  2009-11-09
# 2009-11-10               3 2009-11-10  2009-11-10
# 2009-11-16               6 2009-11-16  2009-11-16
# 2009-11-17               5 2009-11-17  2009-11-17
# 2009-11-18               2 2009-11-18  2009-11-18
# 2009-11-20               7 2009-11-20  2009-11-20
# 2009-11-23               3 2009-11-23  2009-11-23
# 2009-11-24               4 2009-11-24  2009-11-24
# 2009-11-25               6 2009-11-25  2009-11-25
# 2009-11-30               7 2009-11-30  2009-11-30
# 2009-12-01               4 2009-12-01  2009-12-01
# 2009-12-02               1 2009-12-02  2009-12-02
# 2009-12-03               3 2009-12-03  2009-12-03
# 2009-12-04               2 2009-12-04  2009-12-04
# 2009-12-07              23 2009-12-07  2009-12-07
# 2009-12-08               3 2009-12-08  2009-12-08
# 2009-12-09               1 2009-12-09  2009-12-09
# 159  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 160  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 161  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 162  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 163  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 164  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 165  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 166  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 167  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 168  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 169  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 170  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 171  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
# 172  JFK INTERNATIONAL AIRPORT, NY US   40.6386   -73.7622        3.4
#
#            DATE  AWND    ...      WT13  WT14  WT15  WT16  WT17  WT18  WT19  \
# 0    2009-01-16   6.4    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    2009-10-14   3.6    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    2009-11-09   2.8    ...       1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3    2009-11-10   2.9    ...       1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4    2009-11-16   4.4    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5    2009-11-17   3.5    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6    2009-11-18   3.3    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7    2009-11-20   6.2    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 8    2009-11-23   6.2    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 9    2009-11-24   4.3    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 10   2009-11-25   2.6    ...       1.0   1.0   NaN   1.0   NaN   NaN   NaN
# 11   2009-11-30   5.0    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 12   2009-12-01   6.2    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13   2009-12-02   3.9    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 14   2009-12-03   9.8    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 15   2009-12-04   4.1    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 16   2009-12-07   3.6    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17   2009-12-08   4.5    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 18   2009-12-09   7.5    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 19   2009-12-11  10.5    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 20   2009-12-14   4.2    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 21   2009-12-15   4.3    ...       1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 22   2009-12-16   9.1    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23   2009-12-17   8.6    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 24   2009-12-18   4.2    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25   2009-12-22   7.4    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 26   2009-12-23   7.2    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 27   2009-12-24   4.3    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 28   2009-12-28   7.2    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 29   2009-12-29  12.3    ...       NaN   NaN   NaN   1.0   NaN   1.0   NaN
# ..          ...   ...    ...       ...   ...   ...   ...   ...   ...   ...
# 143  2010-06-12   5.4    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 144  2010-06-13   2.5    ...       1.0   1.0   NaN   1.0   NaN   NaN   NaN
# 145  2010-06-14   2.2    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 146  2010-06-15   4.5    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 147  2010-06-16   4.2    ...       1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 148  2010-06-17   6.8    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 149  2010-06-18   3.5    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 150  2010-06-19   4.8    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 151  2010-06-20   4.1    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 152  2010-06-21   4.7    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 153  2010-06-22   3.5    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 154  2010-06-23   4.8    ...       1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 155  2010-06-24   6.1    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 156  2010-06-25   4.6    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 157  2010-06-26   3.2    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 158  2010-06-27   3.1    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 159  2010-06-28   5.4    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 160  2010-06-29   5.7    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 161  2010-06-30   5.9    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 162  2010-07-02   5.1    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 163  2010-07-06   3.1    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164  2010-07-07   3.9    ...       1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 165  2010-07-08   3.4    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 166  2010-07-09   4.2    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 167  2010-07-12   4.2    ...       NaN   NaN   NaN   1.0   NaN   NaN   NaN
# 168  2010-07-13   4.6    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 169  2010-07-14   3.3    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
# 170  2010-07-15   4.3    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 171  2010-07-27   4.7    ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 172  2011-10-27   5.3    ...       1.0   NaN   NaN   1.0   NaN   NaN   NaN
#
#      WT21  WT22      day_y
# 0     NaN   NaN 2009-01-16
# 1     NaN   NaN 2009-10-14
# 2     NaN   NaN 2009-11-09
# 3     NaN   NaN 2009-11-10
# 4     NaN   NaN 2009-11-16
# 5     NaN   NaN 2009-11-17
# 6     NaN   NaN 2009-11-18
# 7     NaN   NaN 2009-11-20
# 8     NaN   NaN 2009-11-23
# 9     NaN   NaN 2009-11-24
# 10    NaN   NaN 2009-11-25
# 11    NaN   NaN 2009-11-30
# 12    NaN   NaN 2009-12-01
# 13    NaN   NaN 2009-12-02
# 14    NaN   NaN 2009-12-03
# 15    NaN   NaN 2009-12-04
# 16    NaN   NaN 2009-12-07
# 17    NaN   NaN 2009-12-08
# 18    NaN   NaN 2009-12-09
# 19    NaN   NaN 2009-12-11
# 20    NaN   NaN 2009-12-14
# 21    NaN   NaN 2009-12-15
# 22    NaN   NaN 2009-12-16
# 23    NaN   NaN 2009-12-17
# 24    NaN   NaN 2009-12-18
# 25    NaN   NaN 2009-12-22
# 26    NaN   NaN 2009-12-23
# 27    NaN   NaN 2009-12-24
# 28    NaN   NaN 2009-12-28
# 29    NaN   NaN 2009-12-29
# ..    ...   ...        ...
# 143   NaN   NaN 2010-06-12
# 144   NaN   NaN 2010-06-13
# 145   NaN   NaN 2010-06-14
# 146   NaN   NaN 2010-06-15
# 147   NaN   NaN 2010-06-16
# 148   NaN   NaN 2010-06-17
# 149   NaN   NaN 2010-06-18
# 150   NaN   NaN 2010-06-19
# 151   NaN   NaN 2010-06-20
# 152   NaN   NaN 2010-06-21
# 153   NaN   NaN 2010-06-22
# 154   NaN   NaN 2010-06-23
# 155   NaN   NaN 2010-06-24
# 156   NaN   NaN 2010-06-25
# 157   NaN   NaN 2010-06-26
# 158   NaN   NaN 2010-06-27
# 159   NaN   NaN 2010-06-28
# 160   NaN   NaN 2010-06-29
# 161   NaN   NaN 2010-06-30
# 162   NaN   NaN 2010-07-02
# 163   NaN   NaN 2010-07-06
# 164   NaN   NaN 2010-07-07
# 165   NaN   NaN 2010-07-08
# 166   NaN   NaN 2010-07-09
# 167   NaN   NaN 2010-07-12
# 168   NaN   NaN 2010-07-13
# 169   NaN   NaN 2010-07-14
# 170   NaN   NaN 2010-07-15
# 171   NaN   NaN 2010-07-27
# 172   NaN   NaN 2011-10-27
#
# [173 rows x 42 columns]

# %%
days_and_weather.columns
# Out:
# Index(['day_counts', 'date', 'day_x', 'STATION', 'NAME', 'LATITUDE',
#        'LONGITUDE', 'ELEVATION', 'DATE', 'AWND', 'FMTM', 'PGTM', 'PRCP',
#        'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'WDF2', 'WDF5', 'WSF2', 'WSF5',
#        'WT01', 'WT02', 'WT03', 'WT04', 'WT05', 'WT06', 'WT07', 'WT08', 'WT09',
#        'WT11', 'WT13', 'WT14', 'WT15', 'WT16', 'WT17', 'WT18', 'WT19', 'WT21',
#        'WT22', 'day_y'],
#       dtype='object')

# %%
days_and_weather["total_precipitation"] = days_and_weather["SNOW"] + days_and_weather["PRCP"]

# %%
import numpy
days_and_weather["precipitation_bool"] = numpy.where(days_and_weather["total_precipitation"]>0, 1,0)

# %%
precip_summary = days_and_weather.groupby('precipitation_bool').agg({'precipitation_bool':'count'})
precip_summary
# Out:
#                     precipitation_bool
# precipitation_bool
# 0                                  124
# 1                                   49

# %%
# days_and_weather

# %%
# inspection_day_counts.reset_index()

# %%
simple_days_and_weather = days_and_weather[["precipitation_bool", "date"]]

# %%
inspection_day_counts.keys()
# Out:
# Index(['day_counts', 'date', 'day'], dtype='object')

# %%
simple_days_and_weather.keys()
# Out:
# Index(['precipitation_bool', 'date'], dtype='object')

# %%
inpections_and_weather =pd.merge(inspection_day_counts,simple_days_and_weather,how='left', left_on='date', right_on='date')

# %%
inpections_and_weather.groupby()
# Out:
#        day_counts  precipitation_bool
# count  173.000000          173.000000
# mean    57.797688            0.283237
# std     37.747318            0.451878
# min      1.000000            0.000000
# 25%     29.000000            0.000000
# 50%     55.000000            0.000000
# 75%     88.000000            1.000000
# max    140.000000            1.000000

# %%
final_answer = inpections_and_weather.groupby("precipitation_bool")["day_counts"].mean()

# %%
final_answer
# Out:
# precipitation_bool
# 0    54.693548
# 1    65.653061
# Name: day_counts, dtype: float64
